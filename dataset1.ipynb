# %% [markdown]
# ## Project 2 Dataset 1

# %%
#import numpy and pandas, and DataFrame / Series
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import datetime

# %%
#Read data from file 'MissingMigrantsDatasetCSV.csv' 
data = pd.read_csv("C:/Users/KATERINE/Documents/cuny classes/DATA ACQ AND MANAGEM/week 6/MissingMigrantsDatasetCSV.csv", encoding='latin-1')
df = pd.DataFrame(data, columns= ['id', 'cause_of_death', 'region_origin', 'affected_nationality', 'missing', 'dead', 'incident_region', 'date', 'source', 'reliability', 'lat', 'Ion'])
print (df)
# Out:
#      id                                     cause_of_death  \
# 0     1                                  Presumed drowning
# 1     3                                    Fell from train
# 2     4                                  Presumed drowning
# 3     6                                           Drowning
# 4     7                                   Vehicle accident
# 5     8                                           Drowning
# 6     9                                           Drowning
# 7    10                                           Drowning
# 8    11                                           Drowning
# 9    12  Died of unknown cause in hospital shortly afte...
# 10   13                                           Drowning
# 11   14                                  Presumed drowning
# 12   15                                  Presumed drowning
# 13   16                                           Drowning
# 14   17         Exposure. Died upon entry to refugee camp.
# ...

# %%
#Reading the last five rows
data.tail()
# Out:
#      id                                     cause_of_death  \
# 94  121                             Drowning, Asphyxiation
# 95  122  Burns from cooking gas explosion in connection...
# 96  123                                           Drowning
# 97  124  Drowning after being thrown overboard by other...
# 98  125                                           Drowning
#
#          region_origin                               affected_nationality  \
# 94                 NaN  Syria, Somalia, Gambia, Ivory Coast, Mali, Tun...
# 95  Sub-Saharan Africa                                 Eritrea or Somalia
# 96  Sub-Saharan Africa               Survivors from Nigeria, Ghana, Niger
# 97  Sub-Saharan Africa                                     Ghana, Nigeria
# 98                 NaN                                                NaN
#
#     missing   dead incident_region        date       source  \
# 94      NaN  750.0   Mediterranean  18/04/2015    IOM Italy
# ...

# %%
#Handling missing values with NULL.   When something is not NULL, it will show a false.  Additionally, it will show true if something is missing
data.isnull().tail()
# Out:
#        id  cause_of_death  region_origin  affected_nationality  missing  \
# 94  False           False           True                 False     True
# 95  False           False          False                 False     True
# 96  False           False          False                 False     True
# 97  False           False          False                 False    False
# 98  False           False           True                  True    False
#
#      dead  incident_region   date  source  reliability    lat    Ion
# 94  False            False  False   False        False  False  False
# 95  False            False  False   False        False  False  False
# 96  False            False  False   False        False  False  False
# 97   True            False  False   False        False  False  False
# 98  False            False  False   False        False  False  False

# %%
#Number of missing values per column
data.isnull().sum()
# Out:
# id                       0
# cause_of_death           7
# region_origin           24
# affected_nationality    46
# missing                 75
# dead                     3
# incident_region          0
# date                     0
# source                   0
# reliability              0
# lat                      0
# Ion                      0
# dtype: int64

# %%
#Examinning subsets of data frame from the cause_of_death column to look for missing values only
data[data.cause_of_death.isnull()]
# Out:
#      id cause_of_death            region_origin affected_nationality  missing  \
# 21   24            NaN                      NaN                  NaN      NaN
# 35   42            NaN                      NaN             Nigerian      NaN
# 43   53            NaN          South East Asia                  NaN      NaN
# 45   57            NaN  Middle East/ South Asia                  NaN      NaN
# 67   83            NaN            South America           Ecuadorian      NaN
# 83  105            NaN       Sub-Saharan Africa             Nigerian      NaN
# 89  112            NaN          South East Asia             Rohingya      NaN
#
#     dead               incident_region        date  \
# 21   8.0                 Mediterranean  20/10/2015
# 35   1.0                 Mediterranean  23/08/2015
# 43  24.0                Southeast Asia  23/08/2015
# 45   1.0                 Mediterranean  18/10/2015
# 67   3.0  Central America incl. Mexico  30/09/2015
# ...

# %%
#Examinning subsets of data frame from the region_origin column to look for missing values only
data[data.region_origin.isnull()]
# Out:
#      id          cause_of_death region_origin  \
# 8    11                Drowning           NaN
# 13   16                Drowning           NaN
# 15   18                Drowning           NaN
# 18   21                Drowning           NaN
# 21   24                     NaN           NaN
# 22   25                Drowning           NaN
# 26   31                Drowning           NaN
# 29   34                Drowning           NaN
# 31   36                Drowning           NaN
# 32   37                Drowning           NaN
# 34   39             Suffocation           NaN
# 35   42                     NaN           NaN
# 37   45                Drowning           NaN
# 40   48                Drowning           NaN
# 50   64            Hit by train           NaN
# 52   66                Drowning           NaN
# 53   67       Presumed drowning           NaN
# 62   76        Vehicle accident           NaN
# 63   77       Presumed drowning           NaN
# ...

# %%
#Examinning subsets of data frame from the affected_nationality column to look for missing values only
data[data.affected_nationality.isnull()]
# Out:
#      id                                     cause_of_death  \
# 2     4                                  Presumed drowning
# 3     6                                           Drowning
# 5     8                                           Drowning
# 6     9                                           Drowning
# 7    10                                           Drowning
# 8    11                                           Drowning
# 12   15                                  Presumed drowning
# 15   18                                           Drowning
# 17   20                                           Drowning
# 18   21                                           Drowning
# 19   22                                           Drowning
# 20   23                                           Drowning
# 21   24                                                NaN
# 22   25                                           Drowning
# 23   28                                           Drowning
# ...

# %%
#Examinning subsets of data frame from the missing column to look for missing values only
data[data.missing.isnull()]
# Out:
#      id                                     cause_of_death  \
# 1     3                                    Fell from train
# 2     4                                  Presumed drowning
# 4     7                                   Vehicle accident
# 5     8                                           Drowning
# 6     9                                           Drowning
# 7    10                                           Drowning
# 9    12  Died of unknown cause in hospital shortly afte...
# 10   13                                           Drowning
# 12   15                                  Presumed drowning
# 13   16                                           Drowning
# 14   17         Exposure. Died upon entry to refugee camp.
# 15   18                                           Drowning
# 16   19                                           Drowning
# 17   20                                           Drowning
# 21   24                                                NaN
# ...

# %%
#Examinning subsets of data frame from the dead column to look for missing values only
data[data.dead.isnull()]
# Out:
#      id                                     cause_of_death  \
# 20   23                                           Drowning
# 77   98                                           Drowning
# 97  124  Drowning after being thrown overboard by other...
#
#               region_origin affected_nationality  missing  dead  \
# 20  Middle East/ South Asia                  NaN      2.0   NaN
# 77  Middle East/ South Asia                  NaN      2.0   NaN
# 97       Sub-Saharan Africa       Ghana, Nigeria     12.0   NaN
#
#    incident_region        date               source         reliability  \
# 20   Mediterranean  29/10/2015                   AP  Partially Verified
# 77   Mediterranean  20/09/2015  Coast Guard Command            Verified
# 97   Mediterranean  16/04/2015          BBC and CBC  Partially Verified
#
#         lat      Ion
# 20  37.7548  26.9778
# 77  39.2357  26.6650
# 97  34.8859  14.4141

# %%
#Total rows and columns in the dataset
data.shape
# Out:
# (99, 12)

# %%
#Absolutely drop records which no describe cause of death (classmate instruction)
data.dropna(subset=['cause_of_death'], how='all').shape
# Out:
# (92, 12)

# %% [markdown]
# ### Conclusion:
# *7 rows containing missing values in the colum,  cause_of_death*
